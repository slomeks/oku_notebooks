# %% [raw]
# ---
# title: check-tldr-fix
# authors:
# - slmk
# tags:
# - test
# created_at: 2019-06-04
# updated_at: 2019-06-04
# tldr: Verify fix in reviewNB.
# ---

# %% [markdown]
# # Is the fix really working?
# Let's try it out.

# %%
a = 2
b = 8
c = 7

(a*b) **c
# Out:
# 268435456

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace (-10*np.pi,10*np.pi, 201)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# All seems fine!
